# %%
from datetime import datetime
import uuid
import pandas as pd
from sqlalchemy.orm import sessionmaker
from sqlalchemy import MetaData
import numpy as np
# from app.database.queries import insert_data
from typing import List, Dict
import logging

# %%
logger = logging.getLogger(__name__)  # Use a named logger

# %%
logging.basicConfig(level=logging.INFO)
RECIPE = "../../app/data/processed/recipe_cleaned.json"
INGREDIENTS = "../../app/data/processed/ingredients_AI.json"
MEAL = "../../app/data/processed/meal_cleaned.json"

# %%
logger.info("PREPARING DATA")
data: pd.DataFrame = pd.read_json(INGREDIENTS)
data = data.replace({np.nan: None, '': None, ' ': None})
data.head()
# Out:
# INFO:__main__:PREPARING DATA
#       main_ingredient quantity weight                         ingredient_id  \
# 0           plantains        3   None  2c2703b4-ed39-468d-a09b-4dda480e3bc7
# 1                milk      2.5   None  2c2703b4-ed39-468d-a09b-4dda480e3bc7
# 2                lime        1   None  2c2703b4-ed39-468d-a09b-4dda480e3bc7
# 3  vanilla bean paste        1   None  2c2703b4-ed39-468d-a09b-4dda480e3bc7
# 4   all purpose flour      2.5   None  2c2703b4-ed39-468d-a09b-4dda480e3bc7
#
#   alternative_ingredient measurement
# 0                   None        None
# 1       plant-based milk        cups
# 2                   None        half
# 3        vanilla extract         tsp
# 4                   None        None

# %%
unique_ingredients = data[["main_ingredient"]].drop_duplicates()
unique_ingredients["ingredientId"] = range(12, len(unique_ingredients) + 12)
recipe_to_ingredients = data.merge(unique_ingredients, on="main_ingredient", how="left")
recipe_to_ingredients.head(3)
# Out:
#   main_ingredient quantity weight                         ingredient_id  \
# 0       plantains        3   None  2c2703b4-ed39-468d-a09b-4dda480e3bc7
# 1            milk      2.5   None  2c2703b4-ed39-468d-a09b-4dda480e3bc7
# 2            lime        1   None  2c2703b4-ed39-468d-a09b-4dda480e3bc7
#
#   alternative_ingredient measurement  ingredientId
# 0                   None        None            12
# 1       plant-based milk        cups            13
# 2                   None        half            14

# %%
alternative_ingredient = data[["alternative_ingredient"]].drop_duplicates()
alternative_ingredient["alternativeOfId"] = range(1, len(alternative_ingredient) + 1)
recipe_to_ingredients = recipe_to_ingredients.merge(alternative_ingredient, on="alternative_ingredient", how="left")
recipe_to_ingredients.head(3)
# Out:
#   main_ingredient quantity weight                         ingredient_id  \
# 0       plantains        3   None  2c2703b4-ed39-468d-a09b-4dda480e3bc7
# 1            milk      2.5   None  2c2703b4-ed39-468d-a09b-4dda480e3bc7
# 2            lime        1   None  2c2703b4-ed39-468d-a09b-4dda480e3bc7
#
#   alternative_ingredient measurement  ingredientId  alternativeOfId
# 0                   None        None            12                1
# 1       plant-based milk        cups            13                2
# 2                   None        half            14                1

# %%
# alt_ingredient = data[["alternative_ingredient"]].drop_duplicates()
# alt_ingredient["alternative_ingredient"] = alt_ingredient[alt_ingredient["alternative_ingredient"] != None]
# alt_ingredient["alternativeOfId"] = range(1, len(alt_ingredient)+1)
# recipe_to_ingredients = recipe_to_ingredients.merge(alt_ingredient, on="alternative_ingredient", how="left")
# recipe_to_ingredients.head(3)

# %%
measurements = data[["measurement"]].drop_duplicates().reset_index(drop=True)
# measurement_AI = pd.read_json("../../app/data/processed/measurements_AI.json")
measurements["measurementId"] = range(6, len(measurements) + 6)
recipe_to_ingredients = recipe_to_ingredients.merge(measurements, on="measurement", how="left")
len(recipe_to_ingredients)
# Out:
# 735

# %%
recipe_to_ingredients = recipe_to_ingredients.rename(columns={"ingredient_id": "recipe_id"})
recipe_to_ingredients.drop(columns=['main_ingredient', "measurement", "weight", "alternative_ingredient"], inplace=True)
data_dict: List[Dict] = recipe_to_ingredients.to_dict(orient='records')  # type: ignore
print(data_dict)
# Out:
# [{'quantity': '3', 'recipe_id': '2c2703b4-ed39-468d-a09b-4dda480e3bc7', 'ingredientId': 12, 'alternativeOfId': 1, 'measurementId': 6}, {'quantity': '2.5', 'recipe_id': '2c2703b4-ed39-468d-a09b-4dda480e3bc7', 'ingredientId': 13, 'alternativeOfId': 2, 'measurementId': 7}, {'quantity': '1', 'recipe_id': '2c2703b4-ed39-468d-a09b-4dda480e3bc7', 'ingredientId': 14, 'alternativeOfId': 1, 'measurementId': 8}, {'quantity': '1', 'recipe_id': '2c2703b4-ed39-468d-a09b-4dda480e3bc7', 'ingredientId': 15, 'alternativeOfId': 3, 'measurementId': 9}, {'quantity': '2.5', 'recipe_id': '2c2703b4-ed39-468d-a09b-4dda480e3bc7', 'ingredientId': 16, 'alternativeOfId': 1, 'measurementId': 6}, {'quantity': '½', 'recipe_id': '2c2703b4-ed39-468d-a09b-4dda480e3bc7', 'ingredientId': 17, 'alternativeOfId': 1, 'measurementId': 6}, {'quantity': '2', 'recipe_id': '2c2703b4-ed39-468d-a09b-4dda480e3bc7', 'ingredientId': 18, 'alternativeOfId': 1, 'measurementId': 9}, {'quantity': '½', 'recipe_id': '2c2703b4-ed39-468d-a09b-4dda480e3bc7', 'ingredientId': 19, 'alternativeOfId': 1, 'measurementId': 6}, {'quantity': '1', 'recipe_id': '2c2703b4-ed39-468d-a09b-4dda480e3bc7', 'ingredientId': 20, 'alternativeOfId': 1, 'measurementId': 10}, {'quantity': None, 'recipe_id': '2c2703b4-ed39-468d-a09b-4dda480e3bc7', 'ingredientId': 21, 'alternativeOfId': 1, 'measurementId': 6}, {'quantity': '2', 'recipe_id': '099498aa-d5d1-4be5-be81-8525014cd5da', 'ingredientId': 22, 'alternativeOfId': 1, 'measurementId': 6}, {'quantity': '57', 'recipe_id': '099498aa-d5d1-4be5-be81-8525014cd5da', 'ingredientId': 23, 'alternativeOfId': 4, 'measurementId': 11}, {'quantity': '3', 'recipe_id': '099498aa-d5d1-4be5-be81-8525014cd5da', 'ingredientId': 24, 'alternativeOfId': 1, 'measurementId': 12}, {'quantity': '0.5', 'recipe_id': '099498aa-d5d1-4be5-be81-8525014cd5da', 'ingredientId': 25, 'alternativeOfId': 1, 'measurementId': 13}, {'quantity': '½', 'recipe_id': '099498aa-d5d1-4be5-be81-8525014cd5da', 'ingredientId': 26, 'alternativeOfId': 1, 'measurementId': 6}, {'quantity': '½', 'recipe_id': '099498aa-d5d1-4be5-be81-8525014cd5da', 'ingredientId': 27, 'alternativeOfId': 1, 'measurementId': 6}, {'quantity': '2', 'recipe_id': '099498aa-d5d1-4be5-be81-8525014cd5da', 'ingredientId': 28, 'alternativeOfId': 1, 'measurementId': 6}, {'quantity': '2', 'recipe_id': '099498aa-d5d1-4be5-be81-8525014cd5da', 'ingredientId': 29, 'alternativeOfId': 5, 'measurementId': 6}, {'quantity': '4', 'recipe_id': '099498aa-d5d1-4be5-be81-8525014cd5da', 'ingredientId': 30, 'alternativeOfId': 6, 'measurementId': 14}, {'quantity': '3', 'recipe_id': '099498aa-d5d1-4be5-be81-8525014cd5da', 'ingredientId': 31, 'alternativeOfId': 1, 'measurementId': 9}, {'quantity': '2', 'recipe_id': '099498aa-d5d1-4be5-be81-8525014cd5da', 'ingredientId': 32, 'alternativeOfId': 1, 'measurementId': 6}, {'quantity': 'to taste', 'recipe_id': '099498aa-d5d1-4be5-be81-8525014cd5da', 'ingredientId': 20, 'alternativeOfId': 1, 'measurementId': 6}, {'quantity': '1.5', 'recipe_id': '9534b335-0657-4da0-abc7-c2a58272f25a', 'ingredientId': 33, 'alternativeOfId': 1, 'measurementId': 7}, {'quantity': '4.5', 'recipe_id': '9534b335-0657-4da0-abc7-c2a58272f25a', 'ingredientId': 34, 'alternativeOfId': 1, 'measurementId': 7}, {'quantity': '0.5', 'recipe_id': '9534b335-0657-4da0-abc7-c2a58272f25a', 'ingredientId': 35, 'alternativeOfId': 1, 'measurementId': 6}, {'quantity': None, 'recipe_id': '9534b335-0657-4da0-abc7-c2a58272f25a', 'ingredientId': 36, 'alternativeOfId': 1, 'measurementId': 6}, {'quantity': None, 'recipe_id': '9534b335-0657-4da0-abc7-c2a58272f25a', 'ingredientId': 37, 'alternativeOfId': 1, 'measurementId': 6}, {'quantity': '1.5', 'recipe_id': '8d378ba0-3b46-4a23-b349-a1a183bbc4ec', 'ingredientId': 38, 'alternativeOfId': 1, 'measurementId': 7}, {'quantity': '2', 'recipe_id': '8d378ba0-3b46-4a23-b349-a1a183bbc4ec', 'ingredientId': 39, 'alternativeOfId': 1, 'measurementId': 6}, {'quantity': '8', 'recipe_id': '8d378ba0-3b46-4a23-b349-a1a183bbc4ec', 'ingredientI ...

# %%
import unicodedata
from fractions import Fraction

unicodes = recipe_to_ingredients[["quantity"]]
unicodes["id"] = range(1, len(unicodes)+1)

unicode_list = unicodes["quantity"]
unicode_id = unicodes['id']

unicode_json = []

def contains_unicode(input_str):
    return any(ord(char) > 127 for char in input_str)

for unicode, id in zip(unicode_list, unicode_id):
    full = 0
    description = ""
    unicode_dict = {}
    if unicode is not None:    
        if contains_unicode(unicode) or "/" in unicode:
            # print(unicode)
            unicode_str = unicodedata.normalize("NFKC", unicode).replace("⁄", "/")
            if ' ' in unicode_str:
                if "-" in unicode_str:
                    parts = unicode_str.split("-")
                    full = float(Fraction(parts[0].strip()))
                else:
                    parts = unicode_str.split()
                    whole_number = int(parts[0])
                    fraction_part = Fraction(parts[1])
                    full = whole_number + float(fraction_part)
            else:
                full = float(Fraction(unicode_str))
        else:
            try:
                full = float(unicode)
            except Exception as e:
                # print(e)
                if isinstance(unicode, str):
                    full = -1
                    description = str(unicode)
                    print(description)
        unicode_dict["id"] = id
        unicode_dict["value"] = full
        unicode_dict["description"] = description
    else:
        full = -1
        description = "None"
        unicode_dict["id"] = id
        unicode_dict["value"] = full
    
    unicode_json.append(unicode_dict.copy())
    
# print(unicode_json)
# Out:
# to taste
# to taste
# to taste
# to taste
# a few
# 15-20
# 3-4
# 20-25
# to taste
# small thumb size
# to taste
# few
# 15-20
# to taste
# 3-4
# 20-25
# a small handful
# 15-20
# /tmp/ipykernel_5955/3087722052.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unicodes["id"] = range(1, len(unicodes)+1)

# %%
quantity_details = pd.DataFrame(unicode_json)
rti_copy = recipe_to_ingredients.copy()

rti_copy["quantity"] = quantity_details["value"]
rti_copy["quantityDescription"] = quantity_details["description"]
rti_copy
# Out:
#      quantity                             recipe_id  ingredientId  \
# 0         3.0  2c2703b4-ed39-468d-a09b-4dda480e3bc7            12
# 1         2.5  2c2703b4-ed39-468d-a09b-4dda480e3bc7            13
# 2         1.0  2c2703b4-ed39-468d-a09b-4dda480e3bc7            14
# 3         1.0  2c2703b4-ed39-468d-a09b-4dda480e3bc7            15
# 4         2.5  2c2703b4-ed39-468d-a09b-4dda480e3bc7            16
# ..        ...                                   ...           ...
# 730       3.0  4b9172ed-03d7-46f3-a207-8eb557f94f00            43
# 731       1.0  4b9172ed-03d7-46f3-a207-8eb557f94f00            61
# 732       2.0  4b9172ed-03d7-46f3-a207-8eb557f94f00            48
# 733       1.0  9250ea88-fa19-4c76-8b33-45aac57863e4            12
# 734      -1.0  9250ea88-fa19-4c76-8b33-45aac57863e4           187
#
#      alternativeOfId  measurementId quantityDescription
# 0                  1              6
# 1                  2              7
# 2                  1              8
# 3                  3              9
# 4                  1              6
# ..               ...            ...                 ...
# 730                1             16
# 731                1             21
# 732                1             44
# 733                1              6
# 734                1              6                 NaN
#
# [735 rows x 6 columns]

# %%
rti_copy = rti_copy.rename(columns={"recipe_id": "recipeId"})
rti_copy["id"] = range(22, len(rti_copy)+22)
rti_copy = rti_copy[["id","quantity", "measurementId", "ingredientId", "alternativeOfId", "recipeId", "quantityDescription"]]
rti_copy
# Out:
#       id  quantity  measurementId  ingredientId  alternativeOfId  \
# 0     22       3.0              6            12                1
# 1     23       2.5              7            13                2
# 2     24       1.0              8            14                1
# 3     25       1.0              9            15                3
# 4     26       2.5              6            16                1
# ..   ...       ...            ...           ...              ...
# 730  752       3.0             16            43                1
# 731  753       1.0             21            61                1
# 732  754       2.0             44            48                1
# 733  755       1.0              6            12                1
# 734  756      -1.0              6           187                1
#
#                                  recipeId quantityDescription
# 0    2c2703b4-ed39-468d-a09b-4dda480e3bc7
# 1    2c2703b4-ed39-468d-a09b-4dda480e3bc7
# 2    2c2703b4-ed39-468d-a09b-4dda480e3bc7
# 3    2c2703b4-ed39-468d-a09b-4dda480e3bc7
# 4    2c2703b4-ed39-468d-a09b-4dda480e3bc7
# ..                                    ...                 ...
# 730  4b9172ed-03d7-46f3-a207-8eb557f94f00
# 731  4b9172ed-03d7-46f3-a207-8eb557f94f00
# 732  4b9172ed-03d7-46f3-a207-8eb557f94f00
# 733  9250ea88-fa19-4c76-8b33-45aac57863e4
# 734  9250ea88-fa19-4c76-8b33-45aac57863e4                 NaN
#
# [735 rows x 7 columns]

# %%
data_dict = rti_copy.to_dict(orient="records")
# insert_data(data=data_dict, schema="RecipeIngredient")

# %%
# u_ingredients = unique_ingredients.rename(columns={"ingredientId" : "id", "main_ingredient": "name"})
# u_ingredients = u_ingredients[["id", "name"]]
# u_ingdict = u_ingredients.to_dict(orient="records")
# insert_data(data=u_ingdict, schema="Ingredient")

# %%
rti_copy
# Out:
#       id  quantity  measurementId  ingredientId  alternativeOfId  \
# 0     22       3.0              6            12                1
# 1     23       2.5              7            13                2
# 2     24       1.0              8            14                1
# 3     25       1.0              9            15                3
# 4     26       2.5              6            16                1
# ..   ...       ...            ...           ...              ...
# 730  752       3.0             16            43                1
# 731  753       1.0             21            61                1
# 732  754       2.0             44            48                1
# 733  755       1.0              6            12                1
# 734  756      -1.0              6           187                1
#
#                                  recipeId quantityDescription
# 0    2c2703b4-ed39-468d-a09b-4dda480e3bc7
# 1    2c2703b4-ed39-468d-a09b-4dda480e3bc7
# 2    2c2703b4-ed39-468d-a09b-4dda480e3bc7
# 3    2c2703b4-ed39-468d-a09b-4dda480e3bc7
# 4    2c2703b4-ed39-468d-a09b-4dda480e3bc7
# ..                                    ...                 ...
# 730  4b9172ed-03d7-46f3-a207-8eb557f94f00
# 731  4b9172ed-03d7-46f3-a207-8eb557f94f00
# 732  4b9172ed-03d7-46f3-a207-8eb557f94f00
# 733  9250ea88-fa19-4c76-8b33-45aac57863e4
# 734  9250ea88-fa19-4c76-8b33-45aac57863e4                 NaN
#
# [735 rows x 7 columns]

# %%
logger.info("PREPARING DATA")
data: pd.DataFrame = pd.read_json(RECIPE)
data = data.replace({np.nan: None, '': None, ' ': None})
data.head()
# Out:
# INFO:__main__:PREPARING DATA
#                               recipe_id                        course  \
# 0  2c2703b4-ed39-468d-a09b-4dda480e3bc7                     Breakfast
# 1  099498aa-d5d1-4be5-be81-8525014cd5da        Main Course, Side Dish
# 2  9534b335-0657-4da0-abc7-c2a58272f25a                     Breakfast
# 3  8d378ba0-3b46-4a23-b349-a1a183bbc4ec  Dinner, Main Course, seafood
# 4  ac3857b2-7a42-4e88-af04-35361b550f2b        Appetizer, Main Course
#
#                               cuisine servings calories  prep time  cook time  \
# 0                        West African      6.0    455.0         15         20
# 1               Cameroonian, Nigerian      8.0    362.0         20         60
# 2  Nigerian, Senegalese, West African      8.0    197.0          5         35
# 3                  Nigerian, Tropical      6.0    428.3         20         30
# 4                            Nigerian      6.0    175.3         20         45
#
#    total time        author keyword  soaking time  marinating time  \
# 0          35          None    None             0                0
# 1          80  Yummy Medley    None             0                0
# 2           0          None    None             0                0
# 3          50  Yummy Medley    None             0                0
# 4           0          None    None             0                0
#
#    cooling time  resting time  wait time
# 0             0             0          0
# 1             0             0          0
# 2             0             0          0
# 3             0             0          0
# 4             0             0          0
